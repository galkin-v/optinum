# %%
import numpy as np

# %%
A = np.array([[1, 2], [3, 4]])

# %%
np.linalg.det(A)
# Out:
# -2.0000000000000004

# %%
?? np.linalg.det

# %%
from optinum.plotting.eigen import plot_gershgorin_circles

# %%
import numpy as np

# %%
A = np.array([[1, 2], [3, 4]])
plot_gershgorin_circles(A)
